# %% [markdown]
# GESTURE-BASED ROCK-PAPER-SCISSORS GAME

# %%
pip install opencv-python mediapipe numpy
# Out:
# Requirement already satisfied: opencv-python in c:\users\navya\anaconda3\lib\site-packages (4.11.0.86)
# Requirement already satisfied: mediapipe in c:\users\navya\appdata\roaming\python\python312\site-packages (0.10.21)
# Requirement already satisfied: numpy in c:\users\navya\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: absl-py in c:\users\navya\anaconda3\lib\site-packages (from mediapipe) (2.2.2)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\navya\anaconda3\lib\site-packages (from mediapipe) (23.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\navya\anaconda3\lib\site-packages (from mediapipe) (25.2.10)
# Requirement already satisfied: jax in c:\users\navya\appdata\roaming\python\python312\site-packages (from mediapipe) (0.6.0)
# Requirement already satisfied: jaxlib in c:\users\navya\appdata\roaming\python\python312\site-packages (from mediapipe) (0.6.0)
# Requirement already satisfied: matplotlib in c:\users\navya\anaconda3\lib\site-packages (from mediapipe) (3.9.2)
# Requirement already satisfied: opencv-contrib-python in c:\users\navya\appdata\roaming\python\python312\site-packages (from mediapipe) (4.11.0.86)
# Requirement already satisfied: protobuf<5,>=4.25.3 in c:\users\navya\anaconda3\lib\site-packages (from mediapipe) (4.25.3)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\navya\appdata\roaming\python\python312\site-packages (from mediapipe) (0.5.1)
# Requirement already satisfied: sentencepiece in c:\users\navya\appdata\roaming\python\python312\site-packages (from mediapipe) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\navya\anaconda3\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: ml_dtypes>=0.5.0 in c:\users\navya\anaconda3\lib\site-packages (from jax->mediapipe) (0.5.1)
# Requirement already satisfied: opt_einsum in c:\users\navya\anaconda3\lib\site-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.11.1 in c:\users\navya\anaconda3\lib\site-packages (from jax->mediapipe) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\navya\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\navya\anaconda3\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\navya\anaconda3\lib\site-packages (from matplotlib->mediapipe) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\navya\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\navya\appdata\roaming\python\python312\site-packages (from matplotlib->mediapipe) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\navya\anaconda3\lib\site-packages (from matplotlib->mediapipe) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\navya\anaconda3\lib\site-packages (from matplotlib->mediapipe) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\navya\appdata\roaming\python\python312\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: pycparser in c:\users\navya\anaconda3\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\navya\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import mediapipe as mp
import numpy as np

mp_hands = mp.solutions.hands
hands = mp_hands.Hands(static_image_mode=False, max_num_hands=2, min_detection_confidence=0.7)
mp_draw = mp.solutions.drawing_utils

def classify_gesture(landmarks):
    finger_tips = [8, 12, 16, 20]
    finger_fold_status = []
    for tip in finger_tips:
        if landmarks[tip][1] < landmarks[tip - 2][1]:
            finger_fold_status.append(1)
        else:
            finger_fold_status.append(0)
    
    # Rock: All fingers folded
    if sum(finger_fold_status) == 0:
        return "Rock"
    # Paper: All fingers open
    elif sum(finger_fold_status) == 4:
        return "Paper"
    # Scissors: Only index and middle open
    elif finger_fold_status == [1, 1, 0, 0]:
        return "Scissors"
    else:
        return "Unknown"

def decide_winner(gesture1, gesture2):
    if gesture1 == gesture2:
        return "Draw!"
    rules = {
        'Rock': 'Scissors',
        'Scissors': 'Paper',
        'Paper': 'Rock'
    }
    if rules.get(gesture1) == gesture2:
        return "Player 1 Wins!"
    else:
        return "Player 2 Wins!"

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    frame = cv2.flip(frame, 1)
    h, w, _ = frame.shape
    results = hands.process(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

    gestures = []
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            lm_list = []
            for lm in hand_landmarks.landmark:
                lm_list.append([int(lm.x * w), int(lm.y * h)])
            gesture = classify_gesture(lm_list)
            gestures.append(gesture)
            mp_draw.draw_landmarks(frame, hand_landmarks, mp_hands.HAND_CONNECTIONS)

    if len(gestures) == 2:
        winner = decide_winner(gestures[0], gestures[1])
        cv2.putText(frame, f"P1: {gestures[0]}", (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255,0), 2)
        cv2.putText(frame, f"P2: {gestures[1]}", (10, 100), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255,0), 2)
        cv2.putText(frame, winner, (10, 150), cv2.FONT_HERSHEY_SIMPLEX, 1.2, (0,0,255), 3)
    else:
        cv2.putText(frame, "Show 2 hands!", (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,0), 2)

    cv2.imshow("Rock Paper Scissors", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
